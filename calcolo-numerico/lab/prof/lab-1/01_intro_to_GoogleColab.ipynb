# %%
#@title <h1>Google Colaboratory in a nutshell</h1>

# %% [markdown]
# <p><img alt="Colaboratory logo" height="45px" src="/img/colab_favicon.ico" align="left" hspace="10px" vspace="0px"></p>
#
# <h1>What is Colaboratory?</h1>

# %% [markdown]
# The Google Colab environment lets you write, run and share codes within Google Drive. The Google Colab document is an exacutable document in which you can write text and code lines.
#
# Colaboratory allows you to write Python codes in your browser.
#
#
# *   No configuration or Python packages downloading are needed
# *   Free access to GPU
# *   Easy sharing
#
# **Who can use Colab?**
# Students, AI reasearchers, Data Scientists, whoever you are. You just need a Google Drive account.

# %% [markdown]
# ![google.PNG](data:image/png;base64,...)

# %% [markdown]
# ![google_account.PNG](data:image/png;base64,...)
#
# This is the link to sign up:
# https://accounts.google.com/signup

# %% [markdown]
# # **Tips on Notebook Document**
#
# This is an interactive environment called **Colab notebook**.
#
# A **notebook document** is composed of cells, each of which can contain code lines,images, text...
#
# Colab connects you to a cloud-based runtime which means that you can execute Python codes without any required setup on your machine.

# %% [markdown]
# This is an example of a **code cell**:

# %%
x = ['Welcome', 'to', 'Calcolo' ,'Numerico' ,'!']
print(x)
# Out:
# ['Welcome', 'to', 'Calcolo', 'Numerico', '!']

# %% [markdown]
# and an example of a **text cell**:

# %% [markdown]
# **Welcome to Calcolo Numerico!!**

# %% [markdown]
# Subsequent code boxes use the same runtime, which means that you may refer to predifined variables. For example:

# %%
for word in x:
  print(word)
# Out:
# Welcome
# to
# Calcolo
# Numerico
# !

# %% [markdown]
# **Remark**: The variable x has been defined two/three cells ago...

# %% [markdown]
# # **References**
#
# A book:
#
# https://link.springer.com/chapter/10.1007/978-1-4842-4470-8_7
#
# or just have a look around on Google and YouTube:
#
# https://colab.research.google.com/notebooks/intro.ipynb?hl=en&pli=1#scrollTo=lSrWNr3MuFUS
#
# https://www.youtube.com/watch?v=inN8seMm7UI
